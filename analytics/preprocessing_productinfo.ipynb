# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Dependencies

# %%
import os
import pandas as pd
import numpy as np
import sklearn
import matplotlib as plt
import seaborn as sns
from IPython import display

# %% [markdown]
# ## Data Collection & Preprocessing

# %%
# File path
train_file_path = '/content/drive/MyDrive/product_info.csv'

# Columns to extract
columns_to_keep = [
    "product_id",
    "product_name",
    "brand_id",
    "brand_name",
    "loves_count",
    "rating",
    "reviews",
    "price_usd",
    "limited_edition",
    "new",
    "highlights",
    "primary_category",
    "secondary_category"
]

# Load the dataset with only the specified columns
try:
    df = pd.read_csv(train_file_path, usecols=columns_to_keep, na_values='?')
    print("Dataset loaded successfully.")
    print("Shape of the filtered dataset:", df.shape)
    print(df.head())  # Display the first few rows of the filtered dataset
except Exception as e:
    print(f"Error loading the dataset: {e}")
# Out:
# Dataset loaded successfully.
# Shape of the filtered dataset: (8494, 13)
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews  price_usd  limited_edition  new  \
# 0  3.6364     11.0       35.0                0    0
# 1  4.1538     13.0      195.0                0    0
# 2  4.2500     16.0      195.0                0    0
# 3  4.4762     21.0      195.0                0    0
# 4  3.2308     13.0      195.0                0    0
#
#                                           highlights primary_category  \
# 0  ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...        Fragrance
# 1  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 2  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 3  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 4  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
#
#   secondary_category
# 0  Value & Gift Sets
# 1              Women
# 2              Women
# 3              Women
# 4              Women

# %% [markdown]
# Number of rows and columns

# %%
df.shape
# Out:
# (8494, 13)

# %% [markdown]
# Transposes the first 5 rows of the DataFrame

# %%
df.head().T
# Out:
#                                                                     0  \
# product_id                                                    P473671
# product_name                                  Fragrance Discovery Set
# brand_id                                                         6342
# brand_name                                                      19-69
# loves_count                                                      6320
# rating                                                         3.6364
# reviews                                                          11.0
# price_usd                                                        35.0
# limited_edition                                                     0
# new                                                                 0
# highlights          ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...
# primary_category                                            Fragrance
# secondary_category                                  Value & Gift Sets
#
#                                                                     1  \
# product_id                                                    P473668
# product_name                                  La Habana Eau de Parfum
# brand_id                                                         6342
# brand_name                                                      19-69
# loves_count                                                      3827
# rating                                                         4.1538
# reviews                                                          13.0
# price_usd                                                       195.0
# limited_edition                                                     0
# new                                                                 0
# highlights          ['Unisex/ Genderless Scent', 'Layerable Scent'...
# primary_category                                            Fragrance
# secondary_category                                              Women
#
#                                                                     2  \
# product_id                                                    P473662
# product_name                                Rainbow Bar Eau de Parfum
# brand_id                                                         6342
# brand_name                                                      19-69
# loves_count                                                      3253
# rating                                                           4.25
# reviews                                                          16.0
# price_usd                                                       195.0
# limited_edition                                                     0
# new                                                                 0
# highlights          ['Unisex/ Genderless Scent', 'Layerable Scent'...
# primary_category                                            Fragrance
# secondary_category                                              Women
#
#                                                                     3  \
# product_id                                                    P473660
# product_name                                     Kasbah Eau de Parfum
# brand_id                                                         6342
# brand_name                                                      19-69
# loves_count                                                      3018
# rating                                                         4.4762
# reviews                                                          21.0
# price_usd                                                       195.0
# limited_edition                                                     0
# new                                                                 0
# highlights          ['Unisex/ Genderless Scent', 'Layerable Scent'...
# primary_category                                            Fragrance
# secondary_category                                              Women
#
#                                                                     4
# product_id                                                    P473658
# product_name                                Purple Haze Eau de Parfum
# brand_id                                                         6342
# brand_name                                                      19-69
# loves_count                                                      2691
# rating                                                         3.2308
# reviews                                                          13.0
# price_usd                                                       195.0
# limited_edition                                                     0
# new                                                                 0
# highlights          ['Unisex/ Genderless Scent', 'Layerable Scent'...
# primary_category                                            Fragrance
# secondary_category                                              Women

# %% [markdown]
# Getting some statistical measures about the data

# %%
df.describe()
# Out:
#           brand_id   loves_count       rating       reviews    price_usd  \
# count  8494.000000  8.494000e+03  8216.000000   8216.000000  8494.000000
# mean   5422.440546  2.917957e+04     4.194513    448.545521    51.655595
# std    1709.595957  6.609212e+04     0.516694   1101.982529    53.669234
# min    1063.000000  0.000000e+00     1.000000      1.000000     3.000000
# 25%    5333.000000  3.758000e+03     3.981725     26.000000    25.000000
# 50%    6157.500000  9.880000e+03     4.289350    122.000000    35.000000
# 75%    6328.000000  2.684125e+04     4.530525    418.000000    58.000000
# max    8020.000000  1.401068e+06     5.000000  21281.000000  1900.000000
#
#        limited_edition          new
# count      8494.000000  8494.000000
# mean          0.070285     0.071698
# std           0.255642     0.258002
# min           0.000000     0.000000
# 25%           0.000000     0.000000
# 50%           0.000000     0.000000
# 75%           0.000000     0.000000
# max           1.000000     1.000000

# %% [markdown]
# Checking the unique values

# %%
df.nunique()
# Out:
# product_id            8494
# product_name          8415
# brand_id               304
# brand_name             304
# loves_count           7436
# rating                4394
# reviews               1556
# price_usd              298
# limited_edition          2
# new                      2
# highlights            4417
# primary_category         9
# secondary_category      41
# dtype: int64

# %% [markdown]
# Getting some informations about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_id            8494 non-null   int64
#  3   brand_name          8494 non-null   object
#  4   loves_count         8494 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   price_usd           8494 non-null   float64
#  8   limited_edition     8494 non-null   int64
#  9   new                 8494 non-null   int64
#  10  highlights          6287 non-null   object
#  11  primary_category    8494 non-null   object
#  12  secondary_category  8486 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 862.8+ KB

# %% [markdown]
# Check the number of missing values in each column

# %%
df.isna().sum()
# Out:
# product_id               0
# product_name             0
# brand_id                 0
# brand_name               0
# loves_count              0
# rating                 278
# reviews                278
# price_usd                0
# limited_edition          0
# new                      0
# highlights            2207
# primary_category         0
# secondary_category       8
# dtype: int64

# %% [markdown]
# ## Handling the Missing Values

# %%
from sklearn.impute import SimpleImputer

# Separate numerical and categorical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

# Impute numerical columns with the mean
num_imp = SimpleImputer(strategy='mean')
df_num_imp = pd.DataFrame(num_imp.fit_transform(df[num_cols]), columns=num_cols)

# Impute categorical columns with the most frequent value
cat_imp = SimpleImputer(strategy='most_frequent')
df_cat_imp = pd.DataFrame(cat_imp.fit_transform(df[cat_cols]), columns=cat_cols)

# Combine the imputed numerical and categorical data back into one dataframe
df_imp = pd.concat([df_num_imp, df_cat_imp], axis=1)

# Check the shape of the imputed dataframe
print(df_imp.shape)

# Print the first few rows to verify the changes
print(df_imp.head())
# Out:
# (8494, 13)
#    brand_id  loves_count  rating  reviews  price_usd  limited_edition  new  \
# 0    6342.0       6320.0  3.6364     11.0       35.0              0.0  0.0
# 1    6342.0       3827.0  4.1538     13.0      195.0              0.0  0.0
# 2    6342.0       3253.0  4.2500     16.0      195.0              0.0  0.0
# 3    6342.0       3018.0  4.4762     21.0      195.0              0.0  0.0
# 4    6342.0       2691.0  3.2308     13.0      195.0              0.0  0.0
#
#   product_id               product_name brand_name  \
# 0    P473671    Fragrance Discovery Set      19-69
# 1    P473668    La Habana Eau de Parfum      19-69
# 2    P473662  Rainbow Bar Eau de Parfum      19-69
# 3    P473660       Kasbah Eau de Parfum      19-69
# 4    P473658  Purple Haze Eau de Parfum      19-69
#
#                                           highlights primary_category  \
# 0  ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...        Fragrance
# 1  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 2  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 3  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 4  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
#
#   secondary_category
# 0  Value & Gift Sets
# 1              Women
# 2              Women
# 3              Women
# 4              Women

# %%
print(df_cat_imp.isna().sum())
print(df_num_imp.isna().sum())
# Out:
# product_id            0
# product_name          0
# brand_name            0
# highlights            0
# primary_category      0
# secondary_category    0
# dtype: int64
# brand_id           0
# loves_count        0
# rating             0
# reviews            0
# price_usd          0
# limited_edition    0
# new                0
# dtype: int64

# %% [markdown]
# ## Outlier Detection and Handling

# %%
# List of numerical columns to check for outliers
numerical_columns = ['rating', 'loves_count', 'reviews']

# Loop through each numerical column to detect outliers
for col in numerical_columns:
    Q1 = df[col].quantile(0.25)  # 25th percentile
    Q3 = df[col].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile range

    # Calculate the lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

# Remove outliers for each numerical column
for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter out rows where the value is an outlier
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print("Data after removing outliers:")
print(df.head())
# Out:
# Data after removing outliers:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews  price_usd  limited_edition  new  \
# 0  3.6364     11.0       35.0                0    0
# 1  4.1538     13.0      195.0                0    0
# 2  4.2500     16.0      195.0                0    0
# 3  4.4762     21.0      195.0                0    0
# 4  3.2308     13.0      195.0                0    0
#
#                                           highlights primary_category  \
# 0  ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...        Fragrance
# 1  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 2  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 3  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 4  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
#
#   secondary_category
# 0  Value & Gift Sets
# 1              Women
# 2              Women
# 3              Women
# 4              Women

# %% [markdown]
# ## Feature Scaling / Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max Scaling
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# Display the scaled data
print(df.head())
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69     0.096675
# 1    P473668    La Habana Eau de Parfum      6342      19-69     0.058540
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69     0.049760
# 3    P473660       Kasbah Eau de Parfum      6342      19-69     0.046165
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69     0.041163
#
#      rating   reviews  price_usd  limited_edition  new  \
# 0  0.258913  0.013717       35.0                0    0
# 1  0.540109  0.016461      195.0                0    0
# 2  0.592391  0.020576      195.0                0    0
# 3  0.715326  0.027435      195.0                0    0
# 4  0.038478  0.016461      195.0                0    0
#
#                                           highlights primary_category  \
# 0  ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...        Fragrance
# 1  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 2  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 3  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
# 4  ['Unisex/ Genderless Scent', 'Layerable Scent'...        Fragrance
#
#   secondary_category
# 0  Value & Gift Sets
# 1              Women
# 2              Women
# 3              Women
# 4              Women

# %% [markdown]
# ## Feature Engineering

# %%
# Create interaction terms
df['rating_reviews'] = df['rating'] * df['reviews']
df['rating_loves_count_reviews'] = df['rating'] * df['loves_count'] * df['reviews']

# Display the updated DataFrame with interaction terms
print(df[['rating', 'loves_count', 'reviews', 'rating_reviews', 'rating_loves_count_reviews']].head())
# Out:
#      rating  loves_count   reviews  rating_reviews  rating_loves_count_reviews
# 0  0.258913     0.096675  0.013717        0.003552                    0.000343
# 1  0.540109     0.058540  0.016461        0.008891                    0.000520
# 2  0.592391     0.049760  0.020576        0.012189                    0.000607
# 3  0.715326     0.046165  0.027435        0.019625                    0.000906
# 4  0.038478     0.041163  0.016461        0.000633                    0.000026

# %% [markdown]
# Calculate sentiment score

# %%
df['sentiment_score'] = (df['rating'] * 0.6) + (df['loves_count'] * 0.2) + (df['reviews'] * 0.2)
print(df['sentiment_score'])
# Out:
# 0       0.177426
# 1       0.339065
# 2       0.369502
# 3       0.443916
# 4       0.034612
#           ...
# 8487    0.120585
# 8488    0.608762
# 8489    0.423856
# 8490    0.640891
# 8491    0.604787
# Name: sentiment_score, Length: 6374, dtype: float64

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and it contains 'primary_category' and 'sentiment_score'
# Create a dictionary to hold the top 10 entries for each primary_category
category_dict = {}

# Group the data by 'primary_category'
grouped = df.groupby('primary_category')

# Extract the top 10 entries for each category based on 'sentiment_score'
for category, group in grouped:
    category_dict[category] = group.nlargest(10, 'sentiment_score')  # Get top 10 by 'sentiment_score'

# Create a plot for each primary_category
for category, top_10 in category_dict.items():
    # Sort by sentiment_score for better visualization
    top_10_sorted = top_10.sort_values(by='sentiment_score', ascending=False)

    # Example plot (replace with your plotting code)
    print(f"Plotting for category: {category}")
    print(top_10_sorted[['product_name', 'sentiment_score']])  # Example output
# Out:
# Plotting for category: Bath & Body
#                                            product_name  sentiment_score
# 6947                 Resurface+ AHA Renewing Body Cream         0.847858
# 5369  The Body Serum - With Hyaluronic Acid, Niacina...         0.832778
# 2790                                   Milk Body Lotion         0.755192
# 2789                                 Milk Body Cleanser         0.744267
# 4290                            Almond Milk Concentrate         0.730640
# 5084                                   Night Body Serum         0.716820
# 2642                   Ingrown Hair Pads with BHA & AHA         0.707600
# 5380  The Body Cream - With 5 Ceramides, Colloidal O...         0.701473
# 2796                          Milk Hydrating Hand Cream         0.687708
# 5829              Melrose Place Moisturizing Body Cream         0.672937
# Plotting for category: Fragrance
#                       product_name  sentiment_score
# 8455         Libre Eau de Toilette         0.782176
# 1929         Sauvage Eau de Parfum         0.762083
# 8148                          Eros         0.760070
# 4373           Idôle Eau de Parfum         0.759509
# 352               Sì Eau de Parfum         0.758764
# 1159  BLEU DE CHANEL Eau de Parfum         0.756469
# 4166    Angels Share Eau De Parfum         0.719553
# 359         Armani Code Pour Femme         0.715915
# 6221                         Ralph         0.714814
# 1066          Good Girl Rollerball         0.714744
# Plotting for category: Gifts
#                   product_name  sentiment_score
# 6782            Lips Gift Card         0.600000
# 6781           Heart Gift Card         0.555048
# 6784                 Gift Card         0.376447
# 6785  Happy Birthday Gift Card         0.316650
# Plotting for category: Hair
#                                      product_name  sentiment_score
# 5805      Treatment Mask for Fine and Medium Hair         0.825248
# 200   Dream Routine Overnight Hydrating Hair Mask         0.783922
# 3871        PEPTIDE PREP Clarifying Detox Shampoo         0.772817
# 717               Hair Thickening Therapy Shampoo         0.770285
# 2844                      Honey Infused Hair Mask         0.768527
# 722           Hair Thickening Therapy Conditioner         0.753431
# 2843           Honey Infused Leave-In Conditioner         0.748976
# 8081        HYDR-8 Deep Moisture Repair Hair Mask         0.741837
# 2846                 Mini Honey Infused Hair Mask         0.733685
# 7080   Brazilian Joia  Milky Leave-In Conditioner         0.715934
# Plotting for category: Makeup
#                                            product_name  sentiment_score
# 5930          Major Dimension II Rose Eyeshadow Palette         0.882197
# 3878  Face Bento Cream Bronzer, Powder Blush & Highl...         0.832080
# 3256                                  Veil Powder Brush         0.826735
# 2558                                     Gloss Bomb Ice         0.815732
# 7861                         Cloud Crush Blurring Blush         0.812497
# 283                                   Stick Cream Blush         0.809035
# 5926                               Major Glow Lip Shine         0.806804
# 655                                             Bronzer         0.805807
# 3257                    Vanish Flash Highlighting Stick         0.791236
# 6475  Microsmooth Multi-Tasking Baked Face Powder Fo...         0.788335
# Plotting for category: Men
#                                            product_name  sentiment_score
# 3635                      Beard Lube Conditioning Shave         0.686283
# 3632                         Face Buff Energizing Scrub         0.626992
# 1543  Clinique For Men Maximum Hydrator 72-Hour Auto...         0.609544
# 4147               Facial Fuel Energizing Tonic For Men         0.609427
# 2043                               K by Dolce & Gabbana         0.604241
# 3149                                          Blade Bin         0.601796
# 3648          Supreme Cream Triple Cushion Shave Lather         0.589435
# 3628  Double-Duty Face Moisturizer Broad Spectrum SP...         0.585375
# 1518              Clinique For Men Anti-Age Moisturizer         0.580076
# 3630                 Deep Dive Glycolic Facial Cleanser         0.579304
# Plotting for category: Mini Size
#                                            product_name  sentiment_score
# 2965           Mini Watermelon Glow AHA Night Treatment         0.770794
# 1870                  Mini Daily Milkfoliant Exfoliator         0.733442
# 593   Mini The POREfessional Deep Retreat Pore-Clear...         0.721426
# 3908  Mini ExfoliKate Intensive Pore Exfoliating Tre...         0.711501
# 2506  Mini Clearly Clean Makeup Removing Cleansing Balm         0.681232
# 596   Mini The POREfessional Tight ’n Toned Pore-Ref...         0.671380
# 4518      Mini The Baby One Talc-Free Eyeshadow Palette         0.663208
# 7031  Smashbox X BECCA Mini Shimmering Skin Perfecto...         0.649171
# 667                      Mini Shimmer Brick Highlighter         0.649045
# 7247  Mini C.E.O. Afterglow Brightening Vitamin C Mo...         0.647659
# Plotting for category: Skincare
#                                            product_name  sentiment_score
# 6065    Pumpkin Enzyme Mask Enzymatic Dermal Resurfacer         0.855403
# 2962                Watermelon Glow AHA Night Treatment         0.837111
# 2649  Ultra Repair Firming Collagen Cream with Pepti...         0.779897
# 5598  Truth Barrier Booster Orange Ferment Vitamin C...         0.778551
# 7207                   Dream Oasis Deep Hydration Serum         0.773401
# 8413     Mini Mandelic Acid + Superfood Unity Exfoliant         0.766143
# 7202                    Cloud Dew Gel Cream Moisturizer         0.759881
# 4949  Great Skin Instant Glow Serum with Niacinamide...         0.754794
# 6529             Nourishing Moisturizer with Prebiotics         0.752002
# 2498  Wake Up Honey Eye Cream with Brightening Vitam...         0.749061
# Plotting for category: Tools & Brushes
#                          product_name  sentiment_score
# 295                          Tweezers         0.678284
# 6561     Total Coverage Angled Sponge         0.668807
# 2462              Scalp Massager Comb         0.626825
# 6729  Angled False Eyelash Applicator         0.610873
# 1680                   The Hair Towel         0.607172
# 6768                   Face Dry Brush         0.604124
# 3904                  The Travel Case         0.603243
# 6650   Total Coverage Original Sponge         0.591922
# 2909        Teeth Whitening GLO Vials         0.581002
# 6579   Beauty on the Fly Reusable Bag         0.568757
